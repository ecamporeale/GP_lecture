# %% [markdown]
# # Gaussian Process Regression
# ## Part III - GPyTorch
# ## SPP summer school on "Machine Learning in Geosciences" in Neustadt/Weinstr. (Germany)
# ### 8 - 10 September 2020
#
# ### Enrico Camporeale (University of Colorado, Boulder & NOAA Space Weather Prediction Center)
# #### enrico.camporeale@noaa.gov
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.<img align="right" width="88" height="31" src=https://i.creativecommons.org/l/by/4.0/88x31.png> <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">

# %% [markdown]
# GPyTorch is a n highly efficient and modular implementation of GPs, with GPU acceleration.
# Implemented in PyTorch.
#
# Developed at Cornell University, Uber AI Labs, and Facebook.
#
# https://gpytorch.ai/
# http://github.com/cornellius-gp/gpytorch

# %% [markdown]
# ## 1D regression
#
# Example adapted from
#
# https://docs.gpytorch.ai/en/v1.1.1/examples/01_Exact_GPs/Simple_GP_Regression.html
#
# We want to solve a regression problem, where the underlying function is
#
# $f=\sin(2\pi x) + \varepsilon$, with $\varepsilon~\mathcal{N}(0,\sigma^2)$

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt

plt.rcParams.update({'font.size': 22})
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Training data is 10 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 1, 10)
# True function is sin(2*pi*x) with Gaussian noise
sigma = math.sqrt(0.04)

def f(x):
    f = torch.sin(x * (2 * math.pi))
    return (f)

train_y = f(train_x) + torch.randn(train_x.size()) * sigma

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ZeroMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# %%
# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=0.1)

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter=100
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/100 - Loss: 0.855   lengthscale: 0.124   noise: 0.032
# Iter 2/100 - Loss: 0.860   lengthscale: 0.113   noise: 0.035
# Iter 3/100 - Loss: 0.855   lengthscale: 0.118   noise: 0.035
# Iter 4/100 - Loss: 0.853   lengthscale: 0.125   noise: 0.035
# Iter 5/100 - Loss: 0.855   lengthscale: 0.131   noise: 0.035
# Iter 6/100 - Loss: 0.854   lengthscale: 0.132   noise: 0.037
# Iter 7/100 - Loss: 0.852   lengthscale: 0.130   noise: 0.039
# Iter 8/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 9/100 - Loss: 0.853   lengthscale: 0.126   noise: 0.044
# Iter 10/100 - Loss: 0.853   lengthscale: 0.125   noise: 0.046
# Iter 11/100 - Loss: 0.853   lengthscale: 0.127   noise: 0.046
# Iter 12/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.047
# Iter 13/100 - Loss: 0.852   lengthscale: 0.131   noise: 0.047
# Iter 14/100 - Loss: 0.853   lengthscale: 0.132   noise: 0.047
# Iter 15/100 - Loss: 0.853   lengthscale: 0.133   noise: 0.047
# Iter 16/100 - Loss: 0.852   lengthscale: 0.132   noise: 0.047
# Iter 17/100 - Loss: 0.852   lengthscale: 0.130   noise: 0.047
# Iter 18/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.047
# Iter 19/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.047
# Iter 20/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.047
# Iter 21/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.046
# Iter 22/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.044
# Iter 23/100 - Loss: 0.852   lengthscale: 0.130   noise: 0.043
# Iter 24/100 - Loss: 0.852   lengthscale: 0.131   noise: 0.042
# Iter 25/100 - Loss: 0.852   lengthscale: 0.130   noise: 0.042
# Iter 26/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.042
# Iter 27/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 28/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.042
# Iter 29/100 - Loss: 0.852   lengthscale: 0.126   noise: 0.042
# Iter 30/100 - Loss: 0.852   lengthscale: 0.125   noise: 0.042
# Iter 31/100 - Loss: 0.852   lengthscale: 0.126   noise: 0.041
# Iter 32/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.041
# Iter 33/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.041
# Iter 34/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.041
# Iter 35/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.041
# Iter 36/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 37/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.042
# Iter 38/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.043
# Iter 39/100 - Loss: 0.852   lengthscale: 0.127   noise: 0.043
# Iter 40/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 41/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 42/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 43/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 44/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.044
# Iter 45/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.044
# Iter 46/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.044
# Iter 47/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.044
# Iter 48/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.044
# Iter 49/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.044
# Iter 50/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.044
# Iter 51/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 52/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 53/100 - Loss: 0.852   lengthscale: 0.129   noise: 0.043
# Iter 54/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 55/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 56/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 57/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 58/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 59/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 60/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 61/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.042
# Iter 62/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 63/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 64/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 65/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 66/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 67/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 68/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 69/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 70/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 71/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 72/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 73/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 74/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 75/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 76/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 77/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 78/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 79/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 80/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 81/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 82/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 83/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 84/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 85/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 86/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 87/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 88/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 89/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 90/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 91/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 92/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 93/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 94/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 95/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 96/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 97/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 98/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 99/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043
# Iter 100/100 - Loss: 0.852   lengthscale: 0.128   noise: 0.043

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 100)
    observed_pred = likelihood(model(test_x))

# %%
plt.rcParams.update({'font.size': 22})
with torch.no_grad():
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x.numpy(), f(test_x).numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)

# %% [markdown]
# ## Non-uniform training data

# %%
train_x = torch.linspace(0, 1, 10)
train_x *= torch.sin(2*math.pi*train_x) +1.0  # we dislocate the training point so they are non-uniform
sigma = 1e-2
train_y = f(train_x) + torch.randn(train_x.size()) * sigma

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)
model.train()
likelihood.train()

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=1e-1)

# Try to change the number of iterations!
training_iter=1000  # We need now a larger number of iterations for training

for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()


# Compare the mll here with the one for uniform training data    
print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))    
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 100)
    observed_pred = likelihood(model(test_x))
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x.numpy(), f(test_x).numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-2, 2])
    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)
# Out:
# Iter 1000/1000 - Loss: -0.915   lengthscale: 0.322   noise: 0.000

# %% [markdown]
# ## Extrapolate to a region with no data

# %%
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 2, 100)
    observed_pred = likelihood(model(test_x))
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x.numpy(), f(test_x).numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-2, 2])
    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)

# %%
from ipywidgets import interactive

initial_length = math.log(0.11)
initial_noise = math.log(0.03)

def interactive_f(lengthscale = initial_length, noise =initial_noise):
    model.covar_module.base_kernel.lengthscale = math.exp(lengthscale)
    model.likelihood.noise = math.exp(noise)
    test_x = torch.linspace(0, 1, 100)
    observed_pred = likelihood(model(test_x))
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.detach().numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x.numpy(), f(test_x).detach().numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.detach().numpy(), upper.detach().numpy(), alpha=0.5)
    ax.set_ylim([-5, 5])
    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)
interactive_plot = interactive(interactive_f, lengthscale = (-4.0, 0.0), noise = (-5.0,0.0))
output = interactive_plot.children[-1]

# %%
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=-2.2072749131897207, description='lengthscale', max=0.0, min=-4.0), Fl…

# %% [markdown]
# ## A single training point separated from the others (not an outlier!)
# ### This is something that a neural network would have a hard time to capture well

# %%
import numpy as np

train_x = torch.linspace(0, 1, 10)
train_x *= torch.sin(2*math.pi*train_x) +1.0  # we dislocate the training point so they are non-uniform
train_y = f(train_x) + torch.randn(train_x.size()) * sigma


train_x = torch.cat((train_x, torch.tensor([2.0])), 0)
train_y = torch.cat((train_y, torch.tensor([2.0])), 0)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)
model.train()
likelihood.train()

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=1e-1)

# Try to change the number of iterations!
training_iter=1000  # We need now a larger number of iterations for training

for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()


# Compare the mll here with the one for uniform training data    
print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))    
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 4.0, 200)
    observed_pred = likelihood(model(test_x))
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Plot true function as red line
#    ax.plot(test_x.numpy(), f(test_x).numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-2, 3])
#    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)
# Out:
# Iter 1000/1000 - Loss: -0.404   lengthscale: 0.362   noise: 0.000

# %% [markdown]
# ## Automatic Relevance Determination

# %%
def f(x):
    x_new = (10*x[:,0]+1*x[:,1]*1e-3*x[:,2]) 
    f = torch.sin(0.4*math.pi*x_new) 
    return (f)

class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(ard_num_dims=3))
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

sigma =1e-2   
train_x = torch.rand(20, 3) # 2-dimensional input
train_y = f(train_x)# + torch.randn(train_x.size(0)) * sigma
    
# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)
model.train()
likelihood.train()

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=1e-1)

# Try to change the number of iterations!
training_iter=1000  # We need now a larger number of iterations for training

for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()

l=model.covar_module.base_kernel.lengthscale.detach().numpy()
for i in range(l.size):
  print(f'Lengthscale dim',i, '= ',l[0,i])
    
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.rand(200, 3) # 5-dimensional input
    observed_pred = likelihood(model(test_x))
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    train_x = (10*train_x[:,0]+1*train_x[:,1]*1e-1*train_x[:,2])
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    test_x_1D = (10*test_x[:,0]+1*test_x[:,1]*1e-1*test_x[:,2])
    s =  np.argsort(test_x_1D.numpy())
    ax.plot(test_x_1D[s].numpy(), observed_pred.mean[s].numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x_1D[s].numpy(), f(test_x)[s].numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x_1D[s].numpy(), lower[s].numpy(), upper[s].numpy(), alpha=0.5)
#    ax.set_ylim([-2, 3])
    ax.legend(['Observed Data', 'Mean', 'True function','Confidence'])
#    ax.legend(['Observed Data', 'Mean', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)
# Out:
# Lengthscale dim 0 =  0.1300413
# Lengthscale dim 1 =  45.29618
# Lengthscale dim 2 =  40.994854

# %% [markdown]
# ## Mean function

# %%
# Training data is 10 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 4*np.pi, 20)
# True function is sin(2*pi*x) with Gaussian noise
sigma = math.sqrt(0.04)

def f(x):
    f = 20*torch.sin(x * (2 * math.pi))+x**2
    return (f)

train_y = f(train_x) + torch.randn(train_x.size()) 


class MyMean(gpytorch.means.Mean):
    def forward(self, input):
  #      print('ciao=',input[:,0].shape)
    #    print(torch.zeros(input.shape[:-1], dtype=input.dtype, device=input.device))
 #       return torch.zeros(input.shape[:-1], dtype=input.dtype, device=input.device)
        return input[:,0]**2

# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = MyMean() # gpytorch.means.ZeroMean()
     #   self.mean_module = gpytorch.means.ConstantMean()
   
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=0.1)

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter=100
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
  #  print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
  #      i + 1, training_iter, loss.item(),
  #      model.covar_module.base_kernel.lengthscale.item(),
  #      model.likelihood.noise.item()
  #  ))
    optimizer.step()

# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 6*np.pi, 200)
    observed_pred = likelihood(model(test_x))


plt.rcParams.update({'font.size': 22})
with torch.no_grad():
    # Initialize plot
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca()
    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.plot(train_x.numpy(), train_y.numpy(), 'k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Plot true function as red line
    ax.plot(test_x.numpy(), f(test_x).numpy(), 'r')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
  #  ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'True function', 'Confidence'])
    ax.set_xlabel('x', fontsize=22)
    ax.set_ylabel('y', fontsize=22)
